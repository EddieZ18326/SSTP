# %%
import numpy as np
import matplotlib
import pandas as pd
import tensorflow as tf

dataset = pd.read_csv('/Users/wzhang/Downloads/lake_erie_habs_W4_6_8_9_12_13_16_2013-2020.xlsx - HAB_data (1).csv')

labels = dataset.iloc[:,16:].values

vals = pd.DataFrame(dataset.iloc[:,4:15].values)

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(vals,labels,test_size=0.2,random_state=0)
X_train = np.array(X_train)

# %%
from keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dropout, Dense, BatchNormalization, GRU, LayerNormalization, MultiHeadAttention,TimeDistributed, Input, Flatten
from sklearn.ensemble import RandomForestRegressor

# %%
def create_GRU():
    model = Sequential()

    model.add(GRU(units=100, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(0.2))

    model.add(GRU(units=100, return_sequences=True))
    model.add(Dropout(0.2))

    model.add(GRU(units=100))
    model.add(Dropout(0.2))

    model.add(Dense(units=1))
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0008), loss='mae')
    model.fit(
        X_train, Y_train, validation_split = 0.2, batch_size=24, epochs=2000
    )
    return model

# %%
from sklearn.linear_model import Lasso
def create_lasso():
    model = Lasso(alpha=100)
    model.fit(X_train,Y_train)
    return model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
def create_LSTM():

    # Define the LSTM model
    model = Sequential()

    model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(0.2))

    model.add(LSTM(units=100, return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(units=100))
    model.add(Dropout(0.2))

    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mean_squared_error')


    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00075), loss='mae')
    # Fit the model to the training data
    history = model.fit(X_train, Y_train, epochs=1000, batch_size=64, validation_data=(X_test, Y_test), shuffle=False)
    return model

# %%
def create_mlp():
    # Initialize MLP model
    mlp_model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(32, activation='relu'),
        Dense(16, activation='relu'),
        Dense(1)  # Output layer for regression task
    ])

    # Compile the model
    mlp_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.001), loss='mae')

    # Print model summary
    mlp_model.summary()

    # Train the model
    history = mlp_model.fit(X_train, Y_train, epochs=300, batch_size=32, validation_split=0.2)

    # Evaluate model performance
    return mlp_model

# %%
def create_rf():
    # Initialize Random Forest regressor
    rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

    # Train the model
    rf_model.fit(X_train, Y_train)
    return rf_model

# %%
from sklearn.linear_model import Ridge
def create_ridge():
    model = Ridge(alpha=100)
    model.fit(X_train,Y_train)
    return model

# %%
from sklearn.svm import SVR
def create_SVM():
    # Initialize SVM regressor
    svm_model = SVR(kernel='rbf', C=10000, gamma='scale')

    # Train the model
    svm_model.fit(X_train, Y_train)
    return svm_model

# %%
gru = create_GRU()
lasso = create_lasso()
lstm = create_LSTM()
mlp = create_mlp()
rf = create_rf()
ridge = create_ridge()
svm = create_SVM()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - loss: 30.0400 - val_loss: 23.6532
# Epoch 2/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 24.2441 - val_loss: 23.2588
# Epoch 3/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 21.8947 - val_loss: 23.1242
# Epoch 4/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 23.9213 - val_loss: 23.0488
# Epoch 5/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 21.3884 - val_loss: 23.0330
# Epoch 6/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 23.3886 - val_loss: 22.9837
# Epoch 7/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 24.4795 - val_loss: 22.9666
# Epoch 8/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 24.2643 - val_loss: 22.9384
# Epoch 9/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 22.9575 - val_loss: 22.9434
# Epoch 10/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 19.2185 - val_loss: 22.9452
# Epoch 11/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 23.8721 - val_loss: 22.9308
# Epoch 12/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 27.2238 - val_loss: 22.8665
# Epoch 13/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 22.8182 - val_loss: 20.5225
# Epoch 14/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 21.3360 - val_loss: 18.9101
# Epoch 15/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 17.1054 - val_loss: 17.9873
# Epoch 16/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 18.0489 - val_loss: 17.5714
# Epoch 17/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 19.1215 - val_loss: 16.8675
# Epoch 18/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 17.6955 - val_loss: 16.5995
# Epoch 19/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 16.5517 - val_loss: 15.9947
# Epoch 20/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 17.9098 - val_loss: 15.9459
# Epoch 21/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 13.6247 - val_loss: 15.6841
# Epoch 22/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 15.9825 - val_loss: 15.1126
# Epoch 23/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 16.2473 - val_loss: 14.7590
# Epoch 24/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 18.2337 - val_loss: 14.6119
# Epoch 25/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 14.9811 - val_loss: 14.3055
# Epoch 26/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 16.4486 - val_loss: 14.0642
# Epoch 27/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 13.7549 - val_loss: 14.0468
# Epoch 28/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 17.1568 - val_loss: 14.0426
# Epoch 29/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 17.5568 - val_loss: 13.9985
# Epoch 30/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 15.4157 - val_loss: 13.7167
# Epoch 31/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.3709 - val_loss: 13.4535
# Epoch 32/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 19.8553 - val_loss: 13.6570
# Epoch 33/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 14.7341 - val_loss: 13.2465
# Epoch 34/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 12.5210 - val_loss: 13.2152
# Epoch 35/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 12.0955 - val_loss: 12.9024
# Epoch 36/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 15.1006 - val_loss: 13.2430
# Epoch 37/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 14.5802 - val_loss: 12.9229
# Epoch 38/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 13.9259 - val_loss: 12.8588
# Epoch 39/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 13.1940 - val_loss: 12.5573
# Epoch 40/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 13.4546 - val_loss: 12.9321
# Epoch 41/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 15.6241 - val_loss: 12.3758
# Epoch 42/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 14.2203 - val_loss: 12.4417
# Epoch 43/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 14.2284 - val_loss: 12.3917
# Epoch 44/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 13.4033 - val_loss: 12.2613
# Epoch 45/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 14.9882 - val_loss: 12.3905
# Epoch 46/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 12.6898 - val_loss: 11.9295
# Epoch 47/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 11.7603 - val_loss: 11.9563
# Epoch 48/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 13.7613 - val_loss: 11.9414
# Epoch 49/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 13.6702 - val_loss: 12.1493
# Epoch 50/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 12.2165 - val_loss: 11.7998
# Epoch 51/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 11.5078 - val_loss: 11.5847
# Epoch 52/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 17.8683 - val_loss: 11.6885
# Epoch 53/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 10.9435 - val_loss: 11.4395
# Epoch 54/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 13.0881 - val_loss: 11.1899
# Epoch 55/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 13.6813 - val_loss: 11.4788
# Epoch 56/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 11.7210 - val_loss: 11.5854
# Epoch 57/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 11.9154 - val_loss: 11.5986
# Epoch 58/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 12.7209 - val_loss: 11.5024
# Epoch 59/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 14.9932 - val_loss: 11.4815
# Epoch 60/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 11.6995 - val_loss: 11.4899
# Epoch 61/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 13.7917 - val_loss: 11.3251
# Epoch 62/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 16.4696 - val_loss: 11.0664
# Epoch 63/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 14.5867 - val_loss: 11.2320
# Epoch 64/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 10.6489 - val_loss: 11.1553
# Epoch 65/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 10.6903 - val_loss: 11.7381
# Epoch 66/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 12.2900 - val_loss: 10.8374
# Epoch 67/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 11.3887 - val_loss: 10.9715
# Epoch 68/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 11.3586 - val_loss: 10.6766
# Epoch 69/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 12.2767 - val_loss: 11.1069
# Epoch 70/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 10.8905 - val_loss: 11.1409
# Epoch 71/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 11.7288 - val_loss: 11.1211
# Epoch 72/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.8860 - val_loss: 10.9146
# Epoch 73/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 12.2851 - val_loss: 11.1173
# Epoch 74/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 10.8548 - val_loss: 10.7980
# Epoch 75/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 10.3635 - val_loss: 10.9494
# Epoch 76/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 12.6980 - val_loss: 10.6638
# Epoch 77/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 11.7065 - val_loss: 10.8869
# Epoch 78/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 11.2030 - val_loss: 10.5961
# Epoch 79/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 11.0801 - val_loss: 10.6347
# Epoch 80/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 11.1838 - val_loss: 10.6313
# Epoch 81/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 13.8640 - val_loss: 10.5451
# Epoch 82/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 11.2204 - val_loss: 10.4214
# Epoch 83/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 12.4916 - val_loss: 10.3844
# Epoch 84/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 11.1998 - val_loss: 10.2869
# Epoch 85/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 12.2242 - val_loss: 10.3432
# Epoch 86/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 13.4975 - val_loss: 10.7453
# Epoch 87/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.6840 - val_loss: 10.3615
# Epoch 88/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 11.6117 - val_loss: 10.3256
# Epoch 89/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 11.4685 - val_loss: 10.2710
# Epoch 90/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 10.5388 - val_loss: 10.4506
# Epoch 91/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.5420 - val_loss: 10.3713
# Epoch 92/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 11.3382 - val_loss: 10.3384
# Epoch 93/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 10.7510 - val_loss: 10.0313
# Epoch 94/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 10.4980 - val_loss: 10.3062
# Epoch 95/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 10.3642 - val_loss: 10.1937
# Epoch 96/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 10.5012 - val_loss: 10.1761
# Epoch 97/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 11.2885 - val_loss: 10.1010
# Epoch 98/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 10.9488 - val_loss: 10.0461
# Epoch 99/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 10.6547 - val_loss: 9.9119
# Epoch 100/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 11.0957 - val_loss: 9.9971
# Epoch 101/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.9254 - val_loss: 10.3070
# Epoch 102/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 12.0954 - val_loss: 10.5676
# Epoch 103/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 10.5090 - val_loss: 10.2396
# Epoch 104/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.3559 - val_loss: 9.7560
# Epoch 105/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.8659 - val_loss: 9.7611
# Epoch 106/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 10.7509 - val_loss: 9.7272
# Epoch 107/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 10.7344 - val_loss: 9.9812
# Epoch 108/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 13.6154 - val_loss: 10.0577
# Epoch 109/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 13.0556 - val_loss: 9.7197
# Epoch 110/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.8663 - val_loss: 9.9675
# Epoch 111/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 11.0990 - val_loss: 10.0998
# Epoch 112/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.8873 - val_loss: 9.3610
# Epoch 113/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.6378 - val_loss: 9.6204
# Epoch 114/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 10.1213 - val_loss: 10.3535
# Epoch 115/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 11.4193 - val_loss: 9.7965
# Epoch 116/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 10.9344 - val_loss: 9.5163
# Epoch 117/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.4911 - val_loss: 9.7518
# Epoch 118/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 10.2296 - val_loss: 10.6163
# Epoch 119/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 10.4025 - val_loss: 9.5375
# Epoch 120/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.6672 - val_loss: 9.6663
# Epoch 121/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 11.9126 - val_loss: 9.6648
# Epoch 122/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.2520 - val_loss: 9.5268
# Epoch 123/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.3032 - val_loss: 9.3821
# Epoch 124/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.4802 - val_loss: 9.5545
# Epoch 125/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.6006 - val_loss: 9.3981
# Epoch 126/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.3960 - val_loss: 9.8095
# Epoch 127/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 10.5753 - val_loss: 9.1941
# Epoch 128/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 10.5531 - val_loss: 9.4568
# Epoch 129/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.4842 - val_loss: 9.5516
# Epoch 130/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.4212 - val_loss: 9.4955
# Epoch 131/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 8.7167 - val_loss: 9.8003
# Epoch 132/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.9757 - val_loss: 9.4301
# Epoch 133/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.1098 - val_loss: 9.0386
# Epoch 134/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 9.9475 - val_loss: 9.2149
# Epoch 135/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 10.4651 - val_loss: 8.9906
# Epoch 136/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.8329 - val_loss: 9.8234
# Epoch 137/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 10.6645 - val_loss: 9.9484
# Epoch 138/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.9393 - val_loss: 9.0268
# Epoch 139/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 8.4172 - val_loss: 9.2109
# Epoch 140/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 10.2790 - val_loss: 9.0530
# Epoch 141/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 9.4477 - val_loss: 9.3941
# Epoch 142/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.6183 - val_loss: 9.6137
# Epoch 143/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 9.8443 - val_loss: 9.3271
# Epoch 144/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 9.0801 - val_loss: 8.9727
# Epoch 145/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 8.7311 - val_loss: 8.7439
# Epoch 146/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.3055 - val_loss: 9.1091
# Epoch 147/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.2340 - val_loss: 9.2229
# Epoch 148/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.0448 - val_loss: 8.6275
# Epoch 149/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.0420 - val_loss: 8.6662
# Epoch 150/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.6926 - val_loss: 8.7643
# Epoch 151/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.6751 - val_loss: 8.7552
# Epoch 152/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.4569 - val_loss: 9.1098
# Epoch 153/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.0519 - val_loss: 9.0169
# Epoch 154/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.8929 - val_loss: 8.7434
# Epoch 155/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.4146 - val_loss: 9.3243
# Epoch 156/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 11.7609 - val_loss: 8.8102
# Epoch 157/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.8761 - val_loss: 9.1454
# Epoch 158/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 10.0949 - val_loss: 9.0934
# Epoch 159/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.0290 - val_loss: 8.5772
# Epoch 160/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.7918 - val_loss: 8.5420
# Epoch 161/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 10.6195 - val_loss: 8.6978
# Epoch 162/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.2206 - val_loss: 8.8867
# Epoch 163/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.9852 - val_loss: 8.6228
# Epoch 164/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.8997 - val_loss: 8.9689
# Epoch 165/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 10.4817 - val_loss: 8.2160
# Epoch 166/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 12.0631 - val_loss: 8.8222
# Epoch 167/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 10.9160 - val_loss: 8.6650
# Epoch 168/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.2283 - val_loss: 8.8989
# Epoch 169/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.9459 - val_loss: 8.6869
# Epoch 170/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 10.4653 - val_loss: 8.7897
# Epoch 171/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 7.0747 - val_loss: 9.1097
# Epoch 172/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.1280 - val_loss: 8.2004
# Epoch 173/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 10.5803 - val_loss: 8.4844
# Epoch 174/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 10.8089 - val_loss: 8.3329
# Epoch 175/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.9838 - val_loss: 8.4576
# Epoch 176/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.8599 - val_loss: 8.5981
# Epoch 177/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.7952 - val_loss: 8.1106
# Epoch 178/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.0485 - val_loss: 8.7878
# Epoch 179/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 7.1243 - val_loss: 8.3489
# Epoch 180/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.4791 - val_loss: 8.4133
# Epoch 181/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.5507 - val_loss: 8.1676
# Epoch 182/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 8.3212 - val_loss: 8.4637
# Epoch 183/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.4854 - val_loss: 8.3630
# Epoch 184/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.7838 - val_loss: 8.3619
# Epoch 185/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.4481 - val_loss: 8.1046
# Epoch 186/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.5645 - val_loss: 8.1982
# Epoch 187/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.9972 - val_loss: 8.4979
# Epoch 188/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 6.7136 - val_loss: 8.2865
# Epoch 189/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.9645 - val_loss: 8.0617
# Epoch 190/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 10.0879 - val_loss: 8.3480
# Epoch 191/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 8.7794 - val_loss: 8.3232
# Epoch 192/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.4373 - val_loss: 8.6815
# Epoch 193/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 11.5677 - val_loss: 8.2531
# Epoch 194/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 7.3358 - val_loss: 8.2855
# Epoch 195/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 7.6709 - val_loss: 9.2447
# Epoch 196/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 10.6448 - val_loss: 8.3510
# Epoch 197/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 9.4503 - val_loss: 7.9045
# Epoch 198/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 9.5064 - val_loss: 8.1484
# Epoch 199/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.6172 - val_loss: 8.4370
# Epoch 200/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 8.4542 - val_loss: 8.0229
# Epoch 201/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 9.4182 - val_loss: 8.2361
# Epoch 202/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 11.1800 - val_loss: 8.3948
# Epoch 203/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.0286 - val_loss: 8.1731
# Epoch 204/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 7.1460 - val_loss: 7.7391
# Epoch 205/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 6.4320 - val_loss: 8.3303
# Epoch 206/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.7128 - val_loss: 8.8136
# Epoch 207/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 10.5714 - val_loss: 9.1629
# Epoch 208/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 9.4116 - val_loss: 8.5003
# Epoch 209/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 8.2216 - val_loss: 8.3606
# Epoch 210/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 8.7251 - val_loss: 8.1552
# Epoch 211/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.3252 - val_loss: 9.1914
# Epoch 212/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.4393 - val_loss: 8.4235
# Epoch 213/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 9.5264 - val_loss: 8.1424
# Epoch 214/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 6.3279 - val_loss: 7.9622
# Epoch 215/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 7.5574 - val_loss: 8.2423
# Epoch 216/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 8.8283 - val_loss: 8.2362
# Epoch 217/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.9651 - val_loss: 8.2411
# Epoch 218/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 8.4481 - val_loss: 8.5195
# Epoch 219/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.1245 - val_loss: 8.3361
# Epoch 220/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 6.7491 - val_loss: 8.1573
# Epoch 221/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 7.2673 - val_loss: 8.3128
# Epoch 222/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 7.2526 - val_loss: 8.2612
# Epoch 223/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 8.2316 - val_loss: 8.5408
# Epoch 224/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.4747 - val_loss: 8.2334
# Epoch 225/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.4077 - val_loss: 8.2380
# Epoch 226/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 5.6479 - val_loss: 7.9596
# Epoch 227/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 6.9830 - val_loss: 8.3329
# Epoch 228/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.7008 - val_loss: 8.4282
# Epoch 229/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.5643 - val_loss: 8.1227
# Epoch 230/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.5058 - val_loss: 8.4056
# Epoch 231/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.9914 - val_loss: 8.2025
# Epoch 232/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.1497 - val_loss: 8.4705
# Epoch 233/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.9203 - val_loss: 8.6803
# Epoch 234/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.4355 - val_loss: 8.4860
# Epoch 235/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 8.7664 - val_loss: 8.2106
# Epoch 236/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 7.6458 - val_loss: 8.7201
# Epoch 237/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.6535 - val_loss: 8.9511
# Epoch 238/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.3361 - val_loss: 8.6502
# Epoch 239/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.4245 - val_loss: 8.0921
# Epoch 240/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.3483 - val_loss: 7.9213
# Epoch 241/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.0977 - val_loss: 9.1389
# Epoch 242/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.7618 - val_loss: 7.9918
# Epoch 243/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 6.0017 - val_loss: 8.0446
# Epoch 244/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 6.9624 - val_loss: 8.3638
# Epoch 245/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 7.0683 - val_loss: 8.3898
# Epoch 246/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 8.0035 - val_loss: 8.5928
# Epoch 247/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.0985 - val_loss: 8.3108
# Epoch 248/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 10.4299 - val_loss: 8.6531
# Epoch 249/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 9.7311 - val_loss: 8.4035
# Epoch 250/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.3473 - val_loss: 8.2323
# Epoch 251/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4694 - val_loss: 8.0270
# Epoch 252/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.2735 - val_loss: 8.0422
# Epoch 253/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 7.0178 - val_loss: 7.9405
# Epoch 254/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 7.1819 - val_loss: 8.1839
# Epoch 255/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 11.2535 - val_loss: 8.6014
# Epoch 256/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.9573 - val_loss: 8.5695
# Epoch 257/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.1208 - val_loss: 8.3935
# Epoch 258/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 8.5283 - val_loss: 8.7832
# Epoch 259/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.5560 - val_loss: 8.5946
# Epoch 260/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.8222 - val_loss: 8.3667
# Epoch 261/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.4246 - val_loss: 8.0797
# Epoch 262/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.7290 - val_loss: 8.4283
# Epoch 263/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.4647 - val_loss: 8.2627
# Epoch 264/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 7.2986 - val_loss: 8.0261
# Epoch 265/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 7.5138 - val_loss: 8.0420
# Epoch 266/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.8711 - val_loss: 8.3364
# Epoch 267/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 6.7606 - val_loss: 8.3663
# Epoch 268/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.5165 - val_loss: 8.3031
# Epoch 269/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 7.6139 - val_loss: 8.5352
# Epoch 270/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.3778 - val_loss: 8.0268
# Epoch 271/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 10.3744 - val_loss: 8.4439
# Epoch 272/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.6631 - val_loss: 8.9654
# Epoch 273/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.8427 - val_loss: 8.1230
# Epoch 274/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 7.2358 - val_loss: 8.2654
# Epoch 275/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.5971 - val_loss: 8.2625
# Epoch 276/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.1927 - val_loss: 8.2661
# Epoch 277/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.8944 - val_loss: 8.5031
# Epoch 278/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 8.3854 - val_loss: 8.2585
# Epoch 279/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.1775 - val_loss: 8.6382
# Epoch 280/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 8.3128 - val_loss: 8.1844
# Epoch 281/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.1059 - val_loss: 7.9305
# Epoch 282/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 6.2534 - val_loss: 8.1942
# Epoch 283/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 9.0345 - val_loss: 8.5136
# Epoch 284/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.6106 - val_loss: 8.4535
# Epoch 285/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 6.5483 - val_loss: 8.7306
# Epoch 286/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.4561 - val_loss: 8.5003
# Epoch 287/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 7.2446 - val_loss: 8.2457
# Epoch 288/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.8086 - val_loss: 8.6546
# Epoch 289/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 7.5289 - val_loss: 8.3702
# Epoch 290/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 9.6850 - val_loss: 8.6510
# Epoch 291/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 7.9667 - val_loss: 8.2366
# Epoch 292/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.2063 - val_loss: 8.3658
# Epoch 293/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.6216 - val_loss: 8.5314
# Epoch 294/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.1501 - val_loss: 8.3059
# Epoch 295/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 8.8401 - val_loss: 8.3016
# Epoch 296/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.2519 - val_loss: 8.3406
# Epoch 297/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.3590 - val_loss: 8.2883
# Epoch 298/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.9243 - val_loss: 8.5609
# Epoch 299/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 7.2483 - val_loss: 8.4617
# Epoch 300/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.8112 - val_loss: 8.1803
# Epoch 301/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.1485 - val_loss: 8.2530
# Epoch 302/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.3475 - val_loss: 8.1007
# Epoch 303/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 6.1354 - val_loss: 8.1999
# Epoch 304/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.3578 - val_loss: 8.0652
# Epoch 305/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.9632 - val_loss: 8.5537
# Epoch 306/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.8390 - val_loss: 8.5334
# Epoch 307/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 6.6799 - val_loss: 8.0834
# Epoch 308/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.5430 - val_loss: 8.4967
# Epoch 309/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 4.8154 - val_loss: 8.6916
# Epoch 310/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 9.3052 - val_loss: 8.2106
# Epoch 311/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 6.6462 - val_loss: 7.9892
# Epoch 312/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 7.0587 - val_loss: 8.2293
# Epoch 313/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 5.5048 - val_loss: 8.5334
# Epoch 314/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 6.9777 - val_loss: 8.6410
# Epoch 315/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 10.6240 - val_loss: 8.4691
# Epoch 316/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 9.3868 - val_loss: 8.3714
# Epoch 317/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 6.7993 - val_loss: 8.7242
# Epoch 318/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 6.9354 - val_loss: 8.5690
# Epoch 319/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.9182 - val_loss: 8.7817
# Epoch 320/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 8.8713 - val_loss: 8.4594
# Epoch 321/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.6834 - val_loss: 8.3147
# Epoch 322/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.2977 - val_loss: 8.4288
# Epoch 323/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 6.0393 - val_loss: 8.5191
# Epoch 324/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.9519 - val_loss: 8.4545
# Epoch 325/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.3693 - val_loss: 8.6799
# Epoch 326/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 5.4612 - val_loss: 8.4200
# Epoch 327/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.9715 - val_loss: 9.0375
# Epoch 328/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.9336 - val_loss: 8.4677
# Epoch 329/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.2764 - val_loss: 8.5527
# Epoch 330/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 9.2270 - val_loss: 8.2645
# Epoch 331/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 5.0329 - val_loss: 8.5556
# Epoch 332/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.4277 - val_loss: 8.8482
# Epoch 333/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.2675 - val_loss: 9.1494
# Epoch 334/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 7.9065 - val_loss: 8.2847
# Epoch 335/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.7814 - val_loss: 8.4732
# Epoch 336/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 8.4721 - val_loss: 8.6326
# Epoch 337/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.0817 - val_loss: 8.6537
# Epoch 338/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.0127 - val_loss: 9.0746
# Epoch 339/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 7.5015 - val_loss: 8.7975
# Epoch 340/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.9672 - val_loss: 8.9088
# Epoch 341/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 7.2647 - val_loss: 8.2501
# Epoch 342/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 8.6817 - val_loss: 8.6352
# Epoch 343/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.1658 - val_loss: 8.3252
# Epoch 344/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 6.2544 - val_loss: 8.6661
# Epoch 345/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 5.3752 - val_loss: 9.1582
# Epoch 346/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 5.3735 - val_loss: 8.1660
# Epoch 347/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 6.1835 - val_loss: 8.2078
# Epoch 348/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 7.0391 - val_loss: 8.7042
# Epoch 349/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 5.3335 - val_loss: 8.5396
# Epoch 350/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 7.0272 - val_loss: 8.5605
# Epoch 351/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.3760 - val_loss: 8.8070
# Epoch 352/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.6443 - val_loss: 9.2145
# Epoch 353/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.8624 - val_loss: 8.6614
# Epoch 354/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.5566 - val_loss: 8.3068
# Epoch 355/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.9828 - val_loss: 8.7566
# Epoch 356/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 10.5943 - val_loss: 8.2842
# Epoch 357/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 7.5503 - val_loss: 8.3864
# Epoch 358/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.7829 - val_loss: 8.3270
# Epoch 359/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.4913 - val_loss: 8.2922
# Epoch 360/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 5.8519 - val_loss: 8.8478
# Epoch 361/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 6.1041 - val_loss: 8.3564
# Epoch 362/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 5.8319 - val_loss: 8.5475
# Epoch 363/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 8.2787 - val_loss: 8.6492
# Epoch 364/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 8.0271 - val_loss: 8.6561
# Epoch 365/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.8710 - val_loss: 8.3624
# Epoch 366/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.9593 - val_loss: 8.1968
# Epoch 367/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 9.0676 - val_loss: 8.3842
# Epoch 368/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 8.3332 - val_loss: 8.4474
# Epoch 369/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 8.8682 - val_loss: 8.5318
# Epoch 370/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.2135 - val_loss: 8.2369
# Epoch 371/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 4.8292 - val_loss: 8.3258
# Epoch 372/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 6.9313 - val_loss: 8.1395
# Epoch 373/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 6.7750 - val_loss: 8.5698
# Epoch 374/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.6032 - val_loss: 8.3285
# Epoch 375/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 5.7850 - val_loss: 8.2894
# Epoch 376/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 6.9662 - val_loss: 8.2759
# Epoch 377/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.0496 - val_loss: 8.1664
# Epoch 378/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 6.6795 - val_loss: 8.9219
# Epoch 379/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.9291 - val_loss: 8.2319
# Epoch 380/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 9.1186 - val_loss: 8.2011
# Epoch 381/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 5.5761 - val_loss: 8.4927
# Epoch 382/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 5.4700 - val_loss: 8.8971
# Epoch 383/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.8997 - val_loss: 8.3437
# Epoch 384/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 5.5731 - val_loss: 8.5029
# Epoch 385/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 6.6712 - val_loss: 8.4653
# Epoch 386/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 6.7855 - val_loss: 8.3516
# Epoch 387/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.0804 - val_loss: 9.0279
# Epoch 388/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 7.2264 - val_loss: 8.4363
# Epoch 389/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.5624 - val_loss: 8.7642
# Epoch 390/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 6.8614 - val_loss: 8.6191
# Epoch 391/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 8.5444 - val_loss: 8.4340
# Epoch 392/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.4004 - val_loss: 8.7513
# Epoch 393/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 4.9272 - val_loss: 8.3808
# Epoch 394/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.7922 - val_loss: 8.1487
# Epoch 395/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 8.0388 - val_loss: 8.5360
# Epoch 396/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.3545 - val_loss: 8.3541
# Epoch 397/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 5.4638 - val_loss: 9.0438
# Epoch 398/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.4570 - val_loss: 9.0020
# Epoch 399/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 8.9484 - val_loss: 8.6118
# Epoch 400/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 5.6011 - val_loss: 8.1953
# Epoch 401/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 5.9127 - val_loss: 8.6280
# Epoch 402/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 6.8097 - val_loss: 8.5306
# Epoch 403/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.2545 - val_loss: 8.5998
# Epoch 404/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 5.7050 - val_loss: 8.6236
# Epoch 405/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 7.0917 - val_loss: 8.3829
# Epoch 406/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 5.8200 - val_loss: 8.3941
# Epoch 407/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 7.2855 - val_loss: 8.6110
# Epoch 408/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 7.2158 - val_loss: 8.5523
# Epoch 409/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.3466 - val_loss: 9.0427
# Epoch 410/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.9940 - val_loss: 8.4995
# Epoch 411/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.3658 - val_loss: 8.5952
# Epoch 412/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.3412 - val_loss: 8.5756
# Epoch 413/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.3028 - val_loss: 8.2625
# Epoch 414/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 5.4760 - val_loss: 8.7108
# Epoch 415/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.4880 - val_loss: 8.8688
# Epoch 416/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.8870 - val_loss: 8.9192
# Epoch 417/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.3194 - val_loss: 8.8407
# Epoch 418/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 8.2921 - val_loss: 8.6027
# Epoch 419/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.9593 - val_loss: 8.8704
# Epoch 420/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 4.2198 - val_loss: 8.8186
# Epoch 421/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.3652 - val_loss: 8.9518
# Epoch 422/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 5.4400 - val_loss: 8.8130
# Epoch 423/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.9415 - val_loss: 9.0193
# Epoch 424/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 4.3834 - val_loss: 9.3410
# Epoch 425/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 8.3695 - val_loss: 8.8886
# Epoch 426/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 8.4357 - val_loss: 8.8459
# Epoch 427/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.4852 - val_loss: 8.2188
# Epoch 428/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.3798 - val_loss: 8.6250
# Epoch 429/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 8.1213 - val_loss: 8.3841
# Epoch 430/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.9555 - val_loss: 9.0457
# Epoch 431/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 5.6488 - val_loss: 9.1929
# Epoch 432/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 8.3023 - val_loss: 8.5425
# Epoch 433/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.7000 - val_loss: 9.0201
# Epoch 434/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.5993 - val_loss: 8.8461
# Epoch 435/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.3922 - val_loss: 8.4724
# Epoch 436/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 7.3736 - val_loss: 8.7274
# Epoch 437/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.4059 - val_loss: 9.1960
# Epoch 438/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 5.3956 - val_loss: 8.0810
# Epoch 439/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.3922 - val_loss: 8.7547
# Epoch 440/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.9265 - val_loss: 8.5849
# Epoch 441/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 6.5494 - val_loss: 9.0650
# Epoch 442/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.1009 - val_loss: 8.4119
# Epoch 443/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.3584 - val_loss: 8.8031
# Epoch 444/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.4509 - val_loss: 8.8558
# Epoch 445/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 8.0143 - val_loss: 8.4019
# Epoch 446/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.3555 - val_loss: 8.8444
# Epoch 447/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.1703 - val_loss: 8.6184
# Epoch 448/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 7.0759 - val_loss: 8.5321
# Epoch 449/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.9660 - val_loss: 8.6325
# Epoch 450/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 7.6822 - val_loss: 8.8611
# Epoch 451/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.5782 - val_loss: 8.4861
# Epoch 452/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.0031 - val_loss: 8.3645
# Epoch 453/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.0283 - val_loss: 8.5386
# Epoch 454/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.8837 - val_loss: 8.5721
# Epoch 455/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.8146 - val_loss: 8.6165
# Epoch 456/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.7475 - val_loss: 8.5595
# Epoch 457/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 7.6156 - val_loss: 8.6242
# Epoch 458/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.6317 - val_loss: 8.4312
# Epoch 459/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.2254 - val_loss: 8.6556
# Epoch 460/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4882 - val_loss: 8.3979
# Epoch 461/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 7.8904 - val_loss: 8.5540
# Epoch 462/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.4329 - val_loss: 8.2103
# Epoch 463/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.8150 - val_loss: 8.5153
# Epoch 464/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.2429 - val_loss: 8.7420
# Epoch 465/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.6114 - val_loss: 8.1121
# Epoch 466/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 6.1637 - val_loss: 8.1416
# Epoch 467/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.9683 - val_loss: 8.8248
# Epoch 468/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 9.8532 - val_loss: 8.4477
# Epoch 469/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.5302 - val_loss: 8.5558
# Epoch 470/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.2422 - val_loss: 8.4133
# Epoch 471/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.5307 - val_loss: 8.7143
# Epoch 472/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.3969 - val_loss: 8.7859
# Epoch 473/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.3868 - val_loss: 9.1280
# Epoch 474/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.2156 - val_loss: 8.6215
# Epoch 475/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.7360 - val_loss: 8.6361
# Epoch 476/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 6.2926 - val_loss: 8.9721
# Epoch 477/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.3882 - val_loss: 8.5105
# Epoch 478/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 4.4178 - val_loss: 8.8332
# Epoch 479/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.2103 - val_loss: 8.9080
# Epoch 480/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.6728 - val_loss: 8.7859
# Epoch 481/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.3818 - val_loss: 8.4171
# Epoch 482/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 5.4085 - val_loss: 8.3750
# Epoch 483/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 7.3848 - val_loss: 8.1423
# Epoch 484/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 8.5949 - val_loss: 8.3852
# Epoch 485/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 6.2926 - val_loss: 8.5795
# Epoch 486/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 8.6191 - val_loss: 8.5169
# Epoch 487/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.6900 - val_loss: 8.5072
# Epoch 488/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.7256 - val_loss: 8.4092
# Epoch 489/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.9497 - val_loss: 8.3704
# Epoch 490/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 7.3311 - val_loss: 8.1745
# Epoch 491/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 7.0029 - val_loss: 8.6843
# Epoch 492/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.8360 - val_loss: 8.2934
# Epoch 493/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 6.3414 - val_loss: 8.6651
# Epoch 494/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.7426 - val_loss: 8.6040
# Epoch 495/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 3.9477 - val_loss: 8.3471
# Epoch 496/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.0972 - val_loss: 8.3650
# Epoch 497/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 6.6090 - val_loss: 8.3104
# Epoch 498/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 4.7196 - val_loss: 8.7954
# Epoch 499/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.9281 - val_loss: 8.4422
# Epoch 500/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 7.7845 - val_loss: 8.7415
# Epoch 501/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 7.0311 - val_loss: 8.4036
# Epoch 502/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 5.5316 - val_loss: 8.8727
# Epoch 503/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 4.4331 - val_loss: 8.4365
# Epoch 504/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.8016 - val_loss: 8.5777
# Epoch 505/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 4.2321 - val_loss: 8.5239
# Epoch 506/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.8468 - val_loss: 8.5072
# Epoch 507/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 6.0841 - val_loss: 8.8319
# Epoch 508/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 5.1904 - val_loss: 8.6632
# Epoch 509/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 7.0923 - val_loss: 8.6870
# Epoch 510/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 7.2671 - val_loss: 8.7706
# Epoch 511/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 5.8966 - val_loss: 8.5877
# Epoch 512/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 6.4925 - val_loss: 8.1402
# Epoch 513/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.5754 - val_loss: 8.5695
# Epoch 514/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.3707 - val_loss: 7.8628
# Epoch 515/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.5567 - val_loss: 8.3852
# Epoch 516/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 7.1474 - val_loss: 8.3439
# Epoch 517/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.5387 - val_loss: 8.3192
# Epoch 518/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.2226 - val_loss: 8.6539
# Epoch 519/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 6.1256 - val_loss: 8.9097
# Epoch 520/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.4503 - val_loss: 8.6892
# Epoch 521/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.9052 - val_loss: 8.6793
# Epoch 522/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 7.7413 - val_loss: 8.7926
# Epoch 523/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.8235 - val_loss: 8.8021
# Epoch 524/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 7.5271 - val_loss: 8.7964
# Epoch 525/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.9719 - val_loss: 8.8800
# Epoch 526/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 8.6977 - val_loss: 8.8134
# Epoch 527/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.9774 - val_loss: 8.6251
# Epoch 528/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 5.8600 - val_loss: 8.8853
# Epoch 529/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.1696 - val_loss: 8.4646
# Epoch 530/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 8.3776 - val_loss: 8.8202
# Epoch 531/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 9.6373 - val_loss: 9.3446
# Epoch 532/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 3.8786 - val_loss: 8.7997
# Epoch 533/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 5.6394 - val_loss: 8.5387
# Epoch 534/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.2476 - val_loss: 9.0878
# Epoch 535/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 6.7036 - val_loss: 8.7954
# Epoch 536/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 4.2401 - val_loss: 9.0404
# Epoch 537/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.8905 - val_loss: 8.8726
# Epoch 538/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 9.0267 - val_loss: 8.6124
# Epoch 539/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.0727 - val_loss: 9.3508
# Epoch 540/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 7.5024 - val_loss: 8.4193
# Epoch 541/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.6288 - val_loss: 9.1590
# Epoch 542/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 6.2782 - val_loss: 8.6147
# Epoch 543/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.4975 - val_loss: 8.4376
# Epoch 544/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.8865 - val_loss: 8.8855
# Epoch 545/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.9179 - val_loss: 8.2889
# Epoch 546/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.2431 - val_loss: 8.4359
# Epoch 547/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.2743 - val_loss: 8.1418
# Epoch 548/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.6910 - val_loss: 8.0293
# Epoch 549/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.0574 - val_loss: 8.2948
# Epoch 550/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.4391 - val_loss: 8.1091
# Epoch 551/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.0097 - val_loss: 8.2341
# Epoch 552/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.9928 - val_loss: 8.4584
# Epoch 553/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.7681 - val_loss: 8.4864
# Epoch 554/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.4194 - val_loss: 8.7072
# Epoch 555/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 7.7543 - val_loss: 8.6419
# Epoch 556/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.7070 - val_loss: 8.7219
# Epoch 557/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.6157 - val_loss: 8.3796
# Epoch 558/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 7.1961 - val_loss: 8.8578
# Epoch 559/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 3.9129 - val_loss: 8.6490
# Epoch 560/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 6.7223 - val_loss: 8.6599
# Epoch 561/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.8908 - val_loss: 8.4933
# Epoch 562/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.3767 - val_loss: 8.8108
# Epoch 563/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 6.5249 - val_loss: 9.1330
# Epoch 564/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3.8710 - val_loss: 8.8803
# Epoch 565/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.4933 - val_loss: 8.5379
# Epoch 566/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.5976 - val_loss: 8.4901
# Epoch 567/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.8826 - val_loss: 8.5274
# Epoch 568/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.1351 - val_loss: 8.8614
# Epoch 569/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.0963 - val_loss: 8.3621
# Epoch 570/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7.1787 - val_loss: 8.9703
# Epoch 571/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.6310 - val_loss: 8.1528
# Epoch 572/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.7372 - val_loss: 8.1857
# Epoch 573/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 6.5863 - val_loss: 8.0238
# Epoch 574/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 5.9692 - val_loss: 8.5861
# Epoch 575/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.9113 - val_loss: 8.4301
# Epoch 576/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.8075 - val_loss: 8.3154
# Epoch 577/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.7216 - val_loss: 8.5711
# Epoch 578/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.2638 - val_loss: 8.6485
# Epoch 579/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.5912 - val_loss: 8.3354
# Epoch 580/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.2921 - val_loss: 8.1751
# Epoch 581/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 8.3938 - val_loss: 8.5687
# Epoch 582/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 5.2741 - val_loss: 8.6307
# Epoch 583/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.7566 - val_loss: 8.9371
# Epoch 584/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5007 - val_loss: 8.6546
# Epoch 585/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 7.0442 - val_loss: 8.4887
# Epoch 586/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.0405 - val_loss: 8.1999
# Epoch 587/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.0812 - val_loss: 8.4335
# Epoch 588/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.8064 - val_loss: 8.2323
# Epoch 589/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.0915 - val_loss: 8.3364
# Epoch 590/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.7956 - val_loss: 8.6222
# Epoch 591/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.5513 - val_loss: 8.7231
# Epoch 592/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.8695 - val_loss: 8.6667
# Epoch 593/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.7974 - val_loss: 8.6913
# Epoch 594/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.1850 - val_loss: 8.4168
# Epoch 595/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.7005 - val_loss: 8.3832
# Epoch 596/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.8575 - val_loss: 8.6909
# Epoch 597/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 10.1152 - val_loss: 8.6383
# Epoch 598/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.8114 - val_loss: 8.7438
# Epoch 599/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 6.0226 - val_loss: 8.3741
# Epoch 600/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 5.9702 - val_loss: 8.6736
# Epoch 601/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.3421 - val_loss: 8.5325
# Epoch 602/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.1207 - val_loss: 8.6165
# Epoch 603/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.7982 - val_loss: 8.5741
# Epoch 604/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.7341 - val_loss: 8.4097
# Epoch 605/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.9688 - val_loss: 8.3266
# Epoch 606/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.7545 - val_loss: 8.1768
# Epoch 607/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.9890 - val_loss: 8.7254
# Epoch 608/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.3149 - val_loss: 8.5204
# Epoch 609/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.7458 - val_loss: 8.3708
# Epoch 610/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.4956 - val_loss: 8.7803
# Epoch 611/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4481 - val_loss: 8.8914
# Epoch 612/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.2935 - val_loss: 8.3852
# Epoch 613/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.2568 - val_loss: 8.2574
# Epoch 614/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.9870 - val_loss: 8.4552
# Epoch 615/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.6889 - val_loss: 8.2716
# Epoch 616/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 6.8103 - val_loss: 8.1693
# Epoch 617/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.0552 - val_loss: 8.5323
# Epoch 618/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.6032 - val_loss: 8.3441
# Epoch 619/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.4724 - val_loss: 8.3427
# Epoch 620/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 5.3800 - val_loss: 8.2989
# Epoch 621/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.5064 - val_loss: 8.5141
# Epoch 622/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.2731 - val_loss: 8.2297
# Epoch 623/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.2213 - val_loss: 9.0051
# Epoch 624/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.2532 - val_loss: 8.5004
# Epoch 625/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 6.0232 - val_loss: 8.6965
# Epoch 626/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.5148 - val_loss: 8.5346
# Epoch 627/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5099 - val_loss: 8.4472
# Epoch 628/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4720 - val_loss: 8.8179
# Epoch 629/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6677 - val_loss: 8.9532
# Epoch 630/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.6376 - val_loss: 8.3609
# Epoch 631/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.4715 - val_loss: 8.4654
# Epoch 632/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4972 - val_loss: 8.3961
# Epoch 633/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.6924 - val_loss: 8.7113
# Epoch 634/2000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.0764 - val_loss: 8.7998
# Epoch 635/2000
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.7786
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 create_GRU()
#       2 create_lasso()
#       3 create_LSTM()
#
# Cell In[7], line 15, in create_GRU()
#      13 model.add(Dense(units=1))
#      14 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0008), loss='mae')
# ---> 15 model.fit(
#      16     X_train, Y_train, validation_split = 0.2, batch_size=24, epochs=2000
#      17 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from deepforest import CascadeForestClassifier

# %%
gruPredict = gru.preidct(X_train)
lassoPredict = lasso.predict(X_train)
lstmPredict = lstm.predict(X_train)
mlpPredict = mlp.predict(X_train)
rfPredict = rf.predict(X_train)
ridgePredict = ridge.predict(X_train)
svmPredict = svm.predict(X_train)
trainData = concatenate([gruPredict,lassoPredict,lstmPredict,mlpPredict,rfPredict,
                         ridgePredict,svmPredict])

# %%
model = CascadeForestClassifier(n_estimators = 50, random_state = 1)

# %%
model.fit(, Y_train)
